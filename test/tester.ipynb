# %%
##### install package instruction

## in local system
# >pip install F:\Projects\Trajectory\implement\HierarchyDetector\HierarchyDetector

## in Google Colab
# !pip install git+https://github.com/saasghari/HierarchyDetector.git

# %%
from  HierarchyDetector import HD
HD.testPackage()
# Out:
# HierarchyDetector v-1.0.0
